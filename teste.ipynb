-- %%
mysql://codespace@localhost:3308?unix_socket=/run/mysqld/mysqld.sock
-- Out:
-- Connected successfully!

-- %%
CREATE DATABASE db;
USE db;
-- Out:
-- Can't create database 'db'; database exists

-- %%
SELECT 1;
-- Out:
--    1
-- 0  1
